# %%
from PIL import Image

# %%
img = Image.open("../datasets/panda.jpg")

# %%
small = img.resize((400, 300))

# %%
small
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x108A57358>

# %%
type(small)
# Out:
# PIL.Image.Image
