# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
small = Image.open("../datasets/RGB_Matte.png")

# %%
small
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x11C4331D0>

# %%
panda = np.array(small)

# %%
type(panda)
# Out:
# numpy.ndarray

# %%
panda.shape
# Out:
# (480, 640, 3)

# %%
red = panda[:, :, 0]
green = panda[:, :, 1]
blue = panda[:, :, 2]

# %%
plt.imshow(blue)

# %%
panda[:, :, [0, 1]] = 0

plt.imshow(panda)
