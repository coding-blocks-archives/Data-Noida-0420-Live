# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
small = Image.open("../datasets/RGB_Matte.png")

# %%
small
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x108A4AE80>

# %%
panda = np.array(small)

# %%
type(panda)
# Out:
# numpy.ndarray

# %%
panda.shape
# Out:
# (300, 400, 3)

# %%
red = panda[:, :, 0]
green = panda[:, :, 1]
blue = panda[:, :, 2]

# %%
plt.imshow(blue)

# %%
panda[:, :, [0, 2]] = 0

plt.imshow(panda)
