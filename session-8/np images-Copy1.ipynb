# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open("../datasets/panda.jpg")

# %%
small = img.resize((400, 300))

# %%
small
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x10B8006D8>

# %%
type(small)
# Out:
# PIL.Image.Image

# %%
panda = np.array(small)

# %%
panda.shape
# Out:
# (300, 400, 3)

# %%
plt.imshow(panda)

# %%
cut = panda[:, 100:300]

# %%
plt.imshow(cut)

# %%
panda[:, :, 1:] = 0

plt.imshow(panda)
