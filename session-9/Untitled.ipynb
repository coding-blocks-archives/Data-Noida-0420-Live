# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 10, 10)

# %%
y = x

# %%
plt.plot(x, y)

# %%
x = [0, 2, 4, 10]

# %%
y = [10, 5, 20, 10]

# %%
plt.plot(x, y)

# %%
x = np.linspace(-10, 10, 100)

# %%
y = x ** 2

# %%
plt.plot(x, x**2)
plt.plot(x, x**3)

# %%
plt.plot(x, x**2)
plt.plot(x, x**3)
plt.xlim(-100, 100)
plt.ylim(-100, 100)
# Out:
# (-100, 100)

# %%
plt.figure()
plt.plot(x, x**2, label="square")
plt.xlabel("Ye mera x ka label")
plt.ylabel("Ye mera y ka label")
plt.title("Poore 20 number")
plt.legend()
plt.xlim(-10, 10)
plt.ylim(-100, 100)
plt.plot(x, x**3, label="cube")

plt.figure()
plt.plot(x, x**2, label="square")
plt.xlabel("Ye mera x ka label Dobara")
plt.ylabel("Ye mera y ka label Dobara")
plt.title("Poore 20 number")
plt.legend()
plt.xlim(-10, 10)
plt.ylim(-100, 100)
plt.plot(x, x**3, label="cube")

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# graph of sin cos tan

# %%
x = np.linspace(-10, 10, 100)

# %%
plt.figure()
plt.plot(x, np.sin(x), label="sin")
plt.plot(x, np.cos(x), label="cos")
plt.plot(x, np.tan(x), label="tan")
plt.legend()
plt.ylim(-4, 4)
plt.show()

# %%
theta = np.linspace(-np.pi, np.pi, 100)
rad = 10000

# %%
x = rad * np.cos(theta)
y = rad * np.sin(theta)

# %%
plt.figure(figsize=(6, 6))
plt.plot(x, y)

# %%
theta = np.linspace(0, 40 * np.pi, 1000)
rad = np.linspace(0, 100, 1000)

# %%
x = rad * np.cos(theta)
y = rad * np.sin(theta)

# %%
plt.figure(figsize=(6, 6))
plt.plot(x, y)

# %%
items = np.random.randint(0, 100, 10000)

another = np.random.randn(10000)

# %%
out = plt.hist(items, bins=20)

# %%
out = plt.hist(another, bins=200)

# %%
x = [10, 20, 30]
explode = 

out = plt.pie(, explode=[.1, 0, 0], shadow=True, startangle=30)

# %%
plt.pie?
# Out:
# Signature:
# plt.pie(
#     x,
#     explode=None,
#     labels=None,
#     colors=None,
#     autopct=None,
#     pctdistance=0.6,
#     shadow=False,
#     labeldistance=1.1,
#     startangle=None,
#     radius=None,
#     counterclock=True,
#     wedgeprops=None,
#     textprops=None,
#     center=(0, 0),
#     frame=False,
#     rotatelabels=False,
#     *,
#     data=None,
# )
# Docstring:
# Plot a pie chart.
#
# Make a pie chart of array *x*.  The fractional area of each wedge is
# given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
# the fractional area directly and the array will not be normalized. The
# resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
# The wedges are plotted counterclockwise, by default starting from the
# x-axis.
#
# Parameters
# ----------
# x : array-like
#     The wedge sizes.
#
# explode : array-like, optional, default: None
#     If not *None*, is a ``len(x)`` array which specifies the fraction
# ...
