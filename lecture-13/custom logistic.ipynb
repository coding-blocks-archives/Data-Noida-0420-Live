# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(centers=4, random_state=42)

# %%
X.shape, y.shape
# Out:
# ((100, 2), (100,))

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
y
# Out:
# array([3, 2, 0, 2, 3, 2, 1, 1, 1, 0, 0, 2, 2, 1, 0, 3, 3, 1, 3, 3, 0, 3,
#        3, 1, 1, 0, 1, 3, 3, 2, 2, 1, 2, 3, 0, 0, 0, 0, 1, 1, 3, 1, 2, 0,
#        0, 2, 2, 3, 3, 1, 1, 1, 1, 2, 3, 3, 0, 0, 1, 0, 2, 1, 3, 2, 3, 3,
#        2, 3, 1, 2, 1, 2, 3, 0, 2, 3, 2, 3, 2, 2, 1, 2, 0, 3, 0, 0, 0, 2,
#        0, 1, 1, 2, 0, 2, 0, 0, 0, 1, 3, 1])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.classes_
# Out:
# array([0, 1, 2, 3])

# %%
model.coef_
# Out:
# array([[ 0.42682721,  0.79225197],
#        [ 0.98262836, -0.38803711],
#        [-0.1887021 , -0.66676541],
#        [-1.22075347,  0.26255055]])

# %%
model.intercept_
# Out:
# array([-0.96237206,  4.75844999,  2.28812141, -6.08419933])

# %%
colors = ["Red", "Yellow", "Green", "Orange", "Black"]

# %%
y_col = [colors[item] for item in y]

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_col)

# %%
# import seaborn as sn

# sn.scatterplot(X[:, 0], X[:, 1], hue=y)

# %%
# plt.scatter(X[:, 0], X[:, 1], c=y_col)

# for [m1, m2], c in zip(model.coef_, model.intercept_):
    
#     x1 = np.linspace(-10, 10, 2)
#     x2 = (-m1/m2)*x1 -(c/m2)
#     plt.plot(x1, x2)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_col)

for index, [[m1, m2], c] in enumerate(zip(model.coef_, model.intercept_)):
    
    x1 = np.linspace(-10, 10, 2)
    x2 = (-m1/m2)*x1 -(c/m2)
    plt.plot(x1, x2, color=colors[index])

plt.xlim(-10, 10)
plt.ylim(-10, 10)
# Out:
# (-10, 10)

# %%
model.score(X, y)
# Out:
# 1.0

# %%
model.predict_proba(X).argmax(axis=1)
# Out:
# array([3, 2, 0, 2, 3, 2, 1, 1, 1, 0, 0, 2, 2, 1, 0, 3, 3, 1, 3, 3, 0, 3,
#        3, 1, 1, 0, 1, 3, 3, 2, 2, 1, 2, 3, 0, 0, 0, 0, 1, 1, 3, 1, 2, 0,
#        0, 2, 2, 3, 3, 1, 1, 1, 1, 2, 3, 3, 0, 0, 1, 0, 2, 1, 3, 2, 3, 3,
#        2, 3, 1, 2, 1, 2, 3, 0, 2, 3, 2, 3, 2, 2, 1, 2, 0, 3, 0, 0, 0, 2,
#        0, 1, 1, 2, 0, 2, 0, 0, 0, 1, 3, 1])

# %%
y
# Out:
# array([3, 2, 0, 2, 3, 2, 1, 1, 1, 0, 0, 2, 2, 1, 0, 3, 3, 1, 3, 3, 0, 3,
#        3, 1, 1, 0, 1, 3, 3, 2, 2, 1, 2, 3, 0, 0, 0, 0, 1, 1, 3, 1, 2, 0,
#        0, 2, 2, 3, 3, 1, 1, 1, 1, 2, 3, 3, 0, 0, 1, 0, 2, 1, 3, 2, 3, 3,
#        2, 3, 1, 2, 1, 2, 3, 0, 2, 3, 2, 3, 2, 2, 1, 2, 0, 3, 0, 0, 0, 2,
#        0, 1, 1, 2, 0, 2, 0, 0, 0, 1, 3, 1])
