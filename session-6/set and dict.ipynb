# %%
d = dict() # fist way

# %%
d = {} # second way

# %%
d["Apple"] = "A sweet red fruit"

# %%
d["Mango"] = "King of fruits"

# %%
d["Grapes"] = "Angoor khatte hai"

# %%
d
# Out:
# {'Apple': 'A sweet red fruit',
#  'Mango': 'King of fruits',
#  'Grapes': 'Angoor khatte hai'}

# %%
keys = d.keys()

# %%
list(keys)
# Out:
# ['Apple', 'Mango', 'Grapes']

# %%
keys[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-6f0aacbbd12d> in <module>()
# ----> 1 keys[0]
#
# TypeError: 'dict_keys' object does not support indexing

# %%
values = d.values()

# %%
values[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b1ad2d7b09ed> in <module>()
# ----> 1 values[0]
#
# TypeError: 'dict_values' object does not support indexing

# %%
d.items()
# Out:
# dict_items([('Apple', 'A sweet red fruit'), ('Mango', 'King of fruits'), ('Grapes', 'Angoor khatte hai')])

# %%
d.items()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-62707639c934> in <module>()
# ----> 1 d.items()[0]
#
# TypeError: 'dict_items' object does not support indexing

# %%
d["Apple"]
# Out:
# 'A sweet red fruit'

# %%
d["Cheeku"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-4cae71a7f55d> in <module>()
# ----> 1 d["Cheeku"]
#
# KeyError: 'Cheeku'

# %%
print(d.get("Cheeku"))
# Out:
# None

# %%
# We will do exception handling later

# try:
#     val = d["Cheeku"]
#     print(val)
#     # + 20 line of code
# except:
#     print("We got some error")

# %%
hash("hello")
# Out:
# -2780559917398431806

# %%
hash("hello")
# Out:
# -2780559917398431806

# %%
# key have to be hashable value can be anything (any type of object)

# %% [markdown]
# ## Set

# %% [markdown]
# - Mutable
# - Iterable
# - Non indexable

# %%
## Set is more like dict with only keys

# %%
s = set()

# %%
s.add(44)

# %%
s.add(55)

# %%
s
# Out:
# {44, 55}

# %%
another = {45, 66, 22, 22, 67, "Hello", (55, 77)}

# %%
another
# Out:
# {(55, 77), 22, 45, 66, 67, 'Hello'}

# %%
a = set("hello")

# %%
b = set("world")

# %%
a, b
# Out:
# ({'e', 'h', 'l', 'o'}, {'d', 'l', 'o', 'r', 'w'})

# %%
a.union(b)
# Out:
# {'d', 'e', 'h', 'l', 'o', 'r', 'w'}

# %%
a.intersection(b)
# Out:
# {'l', 'o'}

# %%
a - b
# Out:
# {'e', 'h'}

# %%
a.difference(b)
# Out:
# {'e', 'h'}
