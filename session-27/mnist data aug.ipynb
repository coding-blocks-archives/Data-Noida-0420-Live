# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
plt.imshow(x_train[300], cmap="gray")

# %%
generator = ImageDataGenerator(rotation_range=15, shear_range=.1, zoom_range=.3)

# %%
flow = generator.flow(x_train.reshape(-1, 28, 28, 1), y_train)

# %%
(x, y) = next(flow)

# %%
x.shape
# Out:
# (32, 28, 28, 1)

# %%
batch = next(flow)
for i in range(len(x)):
    plt.figure()
    plt.imshow(x[i].reshape(28, 28).astype(np.uint8))
    plt.show()
